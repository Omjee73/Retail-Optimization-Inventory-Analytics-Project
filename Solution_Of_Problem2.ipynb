# %%
### Analysis for Secondary stocks...

import pandas as pd
import matplotlib.pyplot as plt

# Data provided by user (manually structured as a sample)
data1 = {
    "Month": ["March", "April", "June", "Jan", "July", "August", "Feb", "May", "Oct", "Nov", "Dec", "Sept"],
    "Sell_Quantity": [126, 75, 65, 131, 84, 73, 24, 67, 136, 155, 56, 42],
    "Purchase_Quantity": [173, 101, 78, 195, 100, 122, 51, 71, 161, 188, 74, 60]
}

# Items per month (added for each month)
items_per_month = {
    "Jan": ["Bikaji Bhujia 400g", "Bikano Bikaneri Bhujia", "Bournvita", "Britannia Cake", "Britannia Cookies",
            "Brooke Bond Red Label Tea", "Cadbury Celebrations", "Closeup Toothpaste", "Cookies", "Dabur Amla Hair Oil",
            "Dove soap", "Oreo Biscuits", "Parachute Coconut Oil", "Parle Candy", "Patanjali Shampoo", "Patanjali Toothpaste",
            "Saffola Oats"],
    "Feb": ["Bikano Bikaneri Bhujia", "Britannia Cookies", "Dukes (snacks)", "Parachute Coconut Oil", "Patanjali Shampoo", "Tata Tea"],
    "March": ["Ayur Herbals Cream", "Bikaji Bhujia 400g", "Bikano Bikaneri Bhujia", "Britannia Cookies", "Cadbury Celebrations",
              "Ching's Masala", "Cookies", "Dabur Amla Hair Oil", "Dabur Red Toothpaste", "Dettol Soap", "Diaper Pants",
              "Dove Moisture", "Dove Shampoo", "Indulekha Oil", "Kissan Tomato Ketchup", "Lipton Green Tea", "Vaseline"],
    "April": ["Britannia Cookies", "Dabur Amla Hair Oil", "Dabur Red Toothpaste", "Dr Oetker Veg Mayonnise", "Dukes (snacks)",
              "Himalaya Facewash", "Indulekha Shampoo", "Kissan Tomato Ketchup", "Parle Candy", "Saffola Oats"],
    "May": ["Bikaji Bhujia 200g", "Cadbury Celebrations", "Cookies", "Gillette Shaving Foam", "Kissan Tomato Ketchup",
            "Parachute Coconut Oil", "Parle Candy", "Patanjali Shampoo", "Tata Tea"],
    "June": ["Cadbury Celebrations", "Ching's Masala", "Dettol Soap", "Eveready cell", "Glucon D", "Horlicks", "Patanjali Facewash",
             "Surf Excel Detergent"],
    "July": ["Britannia Cake", "Cadbury Celebrations", "Dettol Soap", "Dove Shampoo", "Dove soap", "Glow & Lovely Facewash",
             "Himalaya Facewash", "Parle Candy", "Tata Tea", "Vaseline", "Vim Dishwash Bar"],
    "August": ["Britannia Cookies", "Cookies", "Glow & Lovely Facewash", "Glucon D", "Horlicks", "Kellogg's", "Parachute Coconut Oil",
               "Patanjali Toothpaste", "Priyagold Biscuits", "Saffola Oats", "Vaseline"],
    "Sept": ["Bournvita", "Ching's Masala", "Dettol Soap", "Face Wash", "Lotte Candy", "Parle Candy", "Taj Mahal Tea", "Vim Dishwash Bar"],
    "Oct": ["Ayur Herbals Cream", "Bikaji Bhujia 200g", "Brooke Bond Red Label Tea", "Cadbury Celebrations", "Closeup Toothpaste",
            "Dettol Soap", "Horlicks", "Indulekha Shampoo", "Lipton Green Tea", "Oreo Biscuits", "Parachute Coconut Oil",
            "Parle Candy", "Patanjali Facewash", "Priyagold Biscuits", "Saffola Oats", "Surf Excel Detergent"],
    "Nov": ["Bikaji Bhujia 200g", "Chocolate", "Cookies", "Dettol Handwash", "Dettol Soap", "Dr Oetker Veg Mayonnise",
            "Ghadi Detergent Powder", "Himalaya Facewash", "Lipton Green Tea", "Mama Earth Face Wash", "Parachute Coconut Oil",
            "Patanjali Toothpaste", "Priyagold Biscuits", "Surf Excel Detergent", "Taj Mahal Tea", "Vaseline"],
    "Dec": ["Ayur Herbals Cream", "Bikaji Bhujia 200g", "Kellogg's", "Mama Earth Face Wash", "Parachute Coconut Oil",
            "Parle Candy", "Patanjali Toothpaste", "Sunsilk Shampoo"],
}

# Convert to DataFrame
df1 = pd.DataFrame(data1)

# Plot Sales vs Purchases for Data1
plt.figure(figsize=(10, 5))
plt.plot(df1["Month"], df1["Sell_Quantity"], marker='o', linestyle='-', label="Sell Quantity", color='b')
plt.plot(df1["Month"], df1["Purchase_Quantity"], marker='s', linestyle='--', label="Purchase Quantity", color='r')
plt.axhline(y=threshold, color='g', linestyle='-', label="Threshold")  # Corrected threshold plot
plt.xlabel("Month")
plt.ylabel("Quantity")
plt.title("Monthly Sales vs. Purchases (Data1)")
plt.xticks(rotation=45)
plt.legend()
plt.grid(True)
plt.show()

# Calculate threshold
threshold = (df1["Purchase_Quantity"].min() + df1["Purchase_Quantity"].max()) / 2

# Identify months where Sell Quantity exceeds the threshold
high_demand_months = df1[df1["Sell_Quantity"] > threshold].copy()

# Add items for each month in the filtered DataFrame
high_demand_months["Items"] = high_demand_months["Month"].map(items_per_month)

# Convert the list of items into a comma-separated string for better display
high_demand_months["Items"] = high_demand_months["Items"].apply(lambda x: ", ".join(x))

# Reorder the columns to show 'Items' after 'Purchase_Quantity'
high_demand_months = high_demand_months[["Month", "Sell_Quantity", "Purchase_Quantity", "Items"]]

# Show full list without truncation for 'Items' column
pd.set_option('display.max_colwidth', None)

# Print result with added 'Items' column
print("Months where Sell Quantity exceeds threshold with Items:")
print(high_demand_months)
# Out:
# Months where Sell Quantity exceeds threshold with Items:
#    Month  Sell_Quantity  Purchase_Quantity  \
# 0  March            126                173
# 3    Jan            131                195
# 8    Oct            136                161
# 9    Nov            155                188
#
#                                                                                                                                                                                                                                                                                                               Items
# 0             Ayur Herbals Cream, Bikaji Bhujia 400g, Bikano Bikaneri Bhujia, Britannia Cookies, Cadbury Celebrations, Ching's Masala, Cookies, Dabur Amla Hair Oil, Dabur Red Toothpaste, Dettol Soap, Diaper Pants, Dove Moisture, Dove Shampoo, Indulekha Oil, Kissan Tomato Ketchup, Lipton Green Tea, Vaseline
# ...

# %%
### Analysis for Main stocks...

import pandas as pd
import matplotlib.pyplot as plt

# Corrected Dataset
data = {
    "Month": [
        "Apr", "Apr", "Apr", "Apr", "Aug", "Aug", "Aug", "Aug", "Dec", "Dec", "Dec", "Dec", "Dec", "Dec", "Feb", "Feb",
        "Feb", "Feb", "Jan", "Jan", "Jan", "Jan", "Jan", "Jan", "Jan", "Jan", "Jan", "Jan", "Jul", "Jul", "Jul", "Jul",
        "Jun", "Jun", "Jun", "Jun", "Mar", "Mar", "Mar", "Mar", "Mar", "Mar", "Mar", "Mar", "Mar", "Mar", "May", "May",
        "May", "May", "Nov", "Nov", "Nov", "Nov", "Nov", "Nov", "Oct", "Oct", "Oct", "Oct", "Oct", "Oct", "Oct", "Oct",
        "Oct", "Oct", "Sep", "Sep", "Sep", "Sep", "Sep"
    ],
    "SUM of Purchase Qty": [
        30, 35, 40, 60, 20, 20, 25, 35, 15, 25, 45, 50, 70, 80, 40, 40, 50, 70, 15, 20, 25, 30, 50, 50, 80, 100, 25, 25, 25,
        25, 30, 40, 20, 25, 30, 45, 20, 40, 40, 45, 50, 60, 80, 100, 120, 150, 25, 30, 35, 50, 20, 30, 50, 60, 80, 90, 25,
        50, 50, 55, 60, 70, 100, 120, 150, 15, 40, 40, 50, 60
    ],
    "SUM of Sell Qty": [
        28, 32, 38, 55, 18, 18, 22, 32, 14, 23, 42, 48, 68, 75, 35, 38, 45, 65, 14, 18, 23, 28, 48, 48, 75, 95, 22, 22, 22,
        22, 28, 38, 18, 22, 28, 42, 19, 38, 38, 42, 48, 58, 78, 98, 115, 145, 23, 28, 32, 48, 18, 28, 48, 58, 75, 88, 23,
        48, 48, 52, 58, 68, 98, 118, 145, 14, 38, 38, 48, 58
    ],
    "SUM of Profit Monthly": [
        420, 128, 380, 275, 72, 270, 220, 160, 1540, 2300, 210, 720, 1020, 750, 140, 570, 450, 325, 1540, 1260, 2070, 2800,
        240, 720, 1125, 950, 88, 330, 280, 190, 270, 88, 280, 210, 2280, 5320, 3800, 4200, 14400, 464, 1560, 1960, 1725,
        2175, 345, 112, 320, 240, 1980, 2800, 240, 870, 1125, 880, 2760, 6720, 4800, 5200, 17400, 544, 1960, 2360, 2175,
        1540, 190, 570, 720, 580
    ]
}


# Check and adjust list lengths
min_length = min(len(data[col]) for col in data) # Finds the minimum list length in your dictionary.
for col in data:
    data[col] = data[col][:min_length] # Trims longer lists to minimum_length by selecting from the beginning to the minimum_length index.


# Create DataFrame
df = pd.DataFrame(data)

# Group by Month and sum quantities
grouped_df = df.groupby("Month").sum().reset_index()

# Calculate threshold for Purchase Qty
threshold = 300

# Create the graph
plt.figure(figsize=(10, 6))
plt.plot(grouped_df["Month"], grouped_df["SUM of Purchase Qty"], label="SUM of Purchase Qty", marker="o", color="blue")
plt.plot(grouped_df["Month"], grouped_df["SUM of Sell Qty"], label="SUM of Sell Qty", marker="o", color="orange")

# Add threshold line
plt.axhline(y=threshold, color="red", linestyle="--", label=f"Threshold ({threshold})")

# Labeling
plt.title("Monthly Purchase and Sell Trends", fontsize=14)
plt.xlabel("Month", fontsize=12)
plt.ylabel("Quantity", fontsize=12)
plt.legend()
plt.grid(True)

# Find months exceeding threshold for Purchase Qty
exceeding_threshold = grouped_df[grouped_df["SUM of Purchase Qty"] > threshold]

# Display exceeding months
exceeding_list = exceeding_threshold.to_dict(orient="records")
print("Months exceeding threshold for Purchase Quantity:")
for record in exceeding_list:
    print(f"{record},")

plt.show()
# Out:
# Months exceeding threshold for Purchase Quantity:
# {'Month': 'Jan', 'SUM of Purchase Qty': 420, 'SUM of Sell Qty': 393, 'SUM of Profit Monthly': 11123},
# {'Month': 'Mar', 'SUM of Purchase Qty': 705, 'SUM of Sell Qty': 679, 'SUM of Profit Monthly': 30741},
# {'Month': 'Nov', 'SUM of Purchase Qty': 330, 'SUM of Sell Qty': 315, 'SUM of Profit Monthly': 12595},
# {'Month': 'Oct', 'SUM of Purchase Qty': 695, 'SUM of Sell Qty': 672, 'SUM of Profit Monthly': 36739},
